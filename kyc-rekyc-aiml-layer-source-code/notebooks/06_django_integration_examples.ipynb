# %% [markdown]
# # Django Integration Examples
# Shows how Django backend should call AIML APIs after upload or workflow submit.

# %%
import requests, json
payload=json.load(open("../data/sample_agent_payload.json"))
# Start AIML service first: python run_service.py
# requests.post("http://localhost:8010/ai/agents/kyc-evaluate", json=payload).json()

# %%
print("Use aiml_layer/services/django_adapter.py in Django business services to invoke the AIML layer.")
