# %% [markdown]
# # OCR and Document Understanding
# Rule-based baseline extraction with confidence and quality flags.

# %%
import sys
sys.path.append("..")
from aiml_layer.services.ocr_service import OCRExtractionService
from aiml_layer.models.schemas import DocumentExtractionRequest

# %%
svc = OCRExtractionService()
req = DocumentExtractionRequest(document_type="PAN", raw_text="Name AMIT ANDRE Permanent Account Number AABCA1234F DOB 12/08/1980")
svc.extract(req).model_dump()
