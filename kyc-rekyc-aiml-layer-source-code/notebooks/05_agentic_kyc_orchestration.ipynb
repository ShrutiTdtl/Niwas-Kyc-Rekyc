# %% [markdown]
# # Agentic KYC Orchestration
# Runs all agents end-to-end: document extraction, understanding, verification, risk, fraud and compliance decision.

# %%
import sys, json
sys.path.append("..")
from aiml_layer.agents.orchestrator import AgenticKYCOrchestrator

# %%
payload=json.load(open("../data/sample_agent_payload.json"))
result=AgenticKYCOrchestrator().run(payload)
result["agent_decision"]

# %%
result["risk"], result["fraud"], result["identity_verification"]
