# %% [markdown]
# # KYC/Re-KYC Synthetic Data Generation
# Creates demonstrable customer, document, risk and fraud signals for PoC.

# %%
import sys, os
sys.path.append("..")
from scripts.generate_synthetic_kyc_data import build
df = build(100000)
df.head()

# %%
df["risk_label"].value_counts(normalize=True).round(3)

# %%
df.to_csv("../data/synthetic_kyc_100k.csv", index=False)
print("Saved 100000 rows")
